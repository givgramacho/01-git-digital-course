# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## 02. Instalando e configurando o Git
#
# [**Link para baixar**![image-2.png](attachment:image-2.png)![image.png](attachment:image.png)](https://git-scm.com/downloads)
#
# ### Verificar versão do git
# Serve para qualquer comando.
# ![image-3.png](attachment:image-3.png)
#
# ### Tipos de acessos e software do git
#
# - VSCODE Shell
#
# - Github Desktop
#
# - Git por terminal
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ### Comandos git Vscode powershell
#  git config --global user.name "givgramacho"
#
#  git config --global user.email checkcell@hotmail.com

# %% [markdown]
# ## 03. Repositórios do Git
#
#
# ### Copie o código https no repositório
# ![image.png](attachment:image.png)
#
#
#
# ### Depois que cópiou o código no nosso computador terá a pasta
# ![image-2.png](attachment:image-2.png)
#
#
#
# ### Copio o caminho da pasta do computador antes da pasta que criou
# ![image-3.png](attachment:image-3.png)
# C:\Users\Acer\Desktop\Lets_Code Trilhas_FrontBackEnd_FullStack_DataScience\4_TrilhaDigital_DataScience_Santader_Coders2023
#
#
#
# ### Abra o prompt de comando "cmd"
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
#
#
# ### Entrar no promp com comando:
# ![image-6.png](attachment:image-6.png)
# cd "caminho da pasta" conforme figura acima
#
#
# ### Clonar repositório desejado na pasta desejada
# ![image-7.png](attachment:image-7.png)
#
# ![image-8.png](attachment:image-8.png)
# - Clone Digite no ""prompt comando"" da pasta que vai fazer clone do projeto
# clone https://github.com/Letscode-br/lc-challenges-python.git
#
# ### opção de do opção do git desktop
# ![image-9.png](attachment:image-9.png)

# %% [markdown]
# ## 04. Gravando mudanças no repositório
#
# ### Temos um readme.md dentro do repositório
# ![image-2.png](attachment:image-2.png)
#
# ### Possivéis status que o git classifca nossos arquivos no repositório.
#
# ![image-3.png](attachment:image-3.png)
#
#
# ### Verificar status
# git status
#
# ### adiciona as modificações para area de stage
# git add .

# %% [markdown]
# ## 05. Git diff, commit e rm
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ### git diff o que foi modificado
#
# ![image-3.png](attachment:image-3.png)
#
# Linhas que foram acrescentadas está em verde
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
#
# Recuperar e passar o estágio para repositório
#
# ![image-8.png](attachment:image-8.png)
#
# ### git commit -m " mensagem"
#
# ![image-9.png](attachment:image-9.png)
#
# ![image-10.png](attachment:image-10.png)

# %% [markdown]
# ### 06. Git log e restore
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# #### git log traz os ultimos commits que foram feitos
#
# ![image-4.png](attachment:image-4.png)
#
# #### restore para changed
#
# ![image-5.png](attachment:image-5.png)
#
# retorna para area de modified

# %% [markdown]
# ### 07. Repositórios remotos
#
# Interagir com os repositórios remotos
# - git add .
# - git commit -m "mensagem"
# - git remote
# output: origin
# - git push origin master
#
# ![image.png](attachment:image.png)
