# %% [markdown]
# <a href="https://colab.research.google.com/github/givgramacho/01-git-digital-course/blob/main/Get_started_with_uv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Get started with uv
#
# By: Avi Chawla and Akshay Pachaar ([Daily Dose of Data Science](https://join.dailydoseofds.com/))
#
# Note: All commands here start with "!" because you can run shell commands in a Jupyter notebook by adding a "!". When you run them in the terminal, make sure to remove "!".

# %% [markdown]
# ## Install a library with pip

# %%
# Installation with pip (notice the time)

# !pip install crewai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 5.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.3/365.3 kB 26.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 102.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 95.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 79.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.5/119.5 kB 10.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.6/65.6 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 5.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## uv usage guide

# %%
# initialize a new project

# !uv init test-uv
# Out:
# Initialized project `test-uv` at `/content/test-uv`

# %%
# move to the directory

# %cd test-uv
# Out:
# /content/test-uv

# %%
# create a virtual environment

# !uv venv
# Out:
# ...
# Using CPython 3.11.13 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Activate with: source .venv/bin/activate

# %%
# activate the env

# !source .venv/bin/activate

# %%
# Installation with uv

# !uv add crewai
# Out:
# Resolved 143 packages in 2.94s
# ⠙ Preparing packages... (0/140)
# ⠙ Preparing packages... (0/140)
# ⠙ Preparing packages... (0/140)
# ⠙ Preparing packages... (0/140)
# opentelemetry-semantic-conventions ------------------------------     0 B/196.90 KiB
# ⠙ Preparing packages... (0/140)
# opentelemetry-semantic-conventions ------------------------------ 14.92 KiB/196.90 KiB
# ⠙ Preparing packages... (0/140)
# opentelemetry-semantic-conventions ------------------------------ 14.92 KiB/196.90 KiB
# ⠙ Preparing packages... (0/140)
# opentelemetry-semantic-conventions ------------------------------ 14.92 KiB/196.90 KiB
# ⠙ Preparing packages... (0/140)
# fsspec                             ------------------------------     0 B/194.92 KiB
# opentelemetry-semantic-conventions ------------------------------ 14.92 KiB/196.90 KiB
# ⠙ Preparing packages... (0/140)
# fsspec                             ------------------------------ 14.91 KiB/194.92 KiB
# ...

# %% [markdown]
# Now open main.py file and add this:
#
# import firecrawl
#
# Next, open the pyproject.toml file and add this in the dependencies:
#
# "firecrawl-py>=2.13.0"
#
# The dependency file should look like this (without #):

# %%
# [project]
# name = "test-uv"
# version = "0.1.0"
# description = "Add your description here"
# readme = "README.md"
# requires-python = ">=3.11"
# dependencies = [
#     "crewai>=0.134.0",
#     "firecrawl-py>=2.13.0"
# ]

# %% [markdown]
# Notice that firecrawl is not available in our environment yet. Still, the script will run without any errors and firecrawl will be installed by uv:

# %%
# !uv run main.py
# Out:
# Hello from test-uv!

# %%
# !uv sync
# Out:
# Resolved 143 packages in 1ms
# Audited 140 packages in 0.06ms
